# %%
#숫자
#print(2022)
print(45)
# Out:
# 45

# %%
#문자(큰따옴표)
#print("happy")
print("happy")
# Out:
# happy

# %%
#문자(wkrdms따옴표)
#print('happy')
print('happy')
# Out:
# happy

# %%
print(456)
345
# Out:
# 456
# 345

# %%
# 주석입니다
print("파이썬 공부 중") # 출력문
print("파이썬은 쉽다.")
# Out:
# 파이썬 공부 중
# 파이썬은 쉽다.

# %%
# 정수+정수
#print (1+2)
print(2+3)
4+5
# Out:
# 5
# 9

# %%
# 실수 + 정수
# print(3.44+5)
5.5+6
# Out:
# 11.5

# %%
# 문자열 더하기 (합친다)
# print("he"+"llo")
print("he"+"llo")
# Out:
# hello

# %%
# 몫
# 16//3
16//3
# Out:
# 5

# %%
# 나머지
# 16%3
16%3
# Out:
# 1

# %%
# 제곱
# 4**2

4**2
# Out:
# 16

# %%
#정수형
# type(1)
type(3)
# Out:
# int

# %%
# 실수형
# type(1.1)
type(5.5)
# Out:
# float

# %%
# 문자열
# type('hello')
type('hi')
type('3')
# Out:
# str

# %%
# 참/거짓
# type(True)
# type(False)
type(True)
False
# Out:
# False

# %%
# box변수 값에 10 대입
# box = 10
box = 10

# %%
# box변수 값 출력
# print(box)
print(box)
# Out:
# 10

# %%
# box2변수 값에 20 대입
# box2 = 20
box2 = 20

# %%
# 변수(10)+변수(20)
# print(box+box2)
box+box2
# Out:
# 30

# %%
# 30 = 10 + 20
# box3 = box + box2
# print(box3)
box3 = box + box2
print(box3)
# Out:
# 30

# %%
# 20 = 10 + 10
# box = box + box
# print(box)
box = box + box
box
# Out:
# 80

# %%
#str(문자)
# box = '15'
# type(box)
box = '15'
type(box)
# Out:
# str

# %%
box + "10"
# Out:
# '1510'

# %%
box = int(box) + 10
type(box)
# Out:
# int

# %%
#str -> int(숫자)
# box2 = int(box)
# type(box2)

# %%
type(str(box))
box = '60'
int(box)
# Out:
# 60

# %%
# 크다(참)
# 10 > 5
10 > 5
# Out:
# True

# %%
# 작다
10<5
# Out:
# False

# %%
# 같거나 크다
# 10 >= 5
10 >= 5
# Out:
# True

# %%
# 같다
# 10 == 5
10 == 5
# Out:
# False

# %%
# 같지않다
# 10 != 5
10 != 5
# Out:
# True

# %%
# 같다
# a=10
# b=10
# a==b
a=10
b=10
a==b
# Out:
# True

# %%
# 같거나 크다
# a>=b
a>=b
# Out:
# True

# %%
# False
# a>b
a>b
# Out:
# False

# %%
c='빅데이터'
d='빅데이터'
e='데이터'

print(c==d)
print(d==e)
# Out:
# True
# False

# %%
# if True:
#   print("참입니다.")
if True:
  print("참입니다.")
# Out:
# 참입니다.

# %%
# if False:
#   print("실행안됨.")
if False:
  print("거짓")

# %%
box=10
if box < 5:
    print("box가 크다")

# %%
box=1
if box == 10:
    print("box는 10입니다.")
    print("box")
else:
    print("box는 10이 아닙니다.")
# Out:
# box는 10이 아닙니다.

# %%
box=5
if box >= 10:
    print("box는 10 이상입니다.")
else:
    print("box는 10 미만입니다.")
# Out:
# box는 10 미만입니다.

# %%
box=7
if box >= 10:
    print("box는 10 이상입니다.")
elif box <10 and :
else:
    print("box는 10 미만입니다.")

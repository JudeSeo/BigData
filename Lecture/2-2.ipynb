# %%
# 여러개의 값을 담을 때 여러개의 변수 사용?
box1 = 4
box2 = 2
box3 = 10
box4 = 6
box5 = 8

# %%
# 리스트 변수
# listbox = [4, 2, 10, 6, 8]
# print(listbox)

listbox=[1,2,3,4,5,6,7,8]
listbox
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# type
type(listbox)
# Out:
# list

# %%
# 문자열
# listbox=['네모','세모','동그라미']
# print(listbox)
listbox=['네모','세모','동그라미', 3, 4, 5]
listbox
# Out:
# ['네모', '세모', '동그라미', 3, 4, 5]

# %%
# 추가
# listbox.append('별')
# print(listbox)
listbox.append('별')
listbox
# Out:
# ['네모', '세모', '동그라미', 3, 4, 5, '별']

# %%
# listbox=[4,2,10,6,8]
listbox=['네모','세모','동그라미']
listbox.sort()
listbox
# Out:
# ['네모', '동그라미', '세모']

# %%
# 딕셔너리
# dictbox = {'name':'네모','level':5}
# print(dictbox);
di = {'name':'sam','level':5}
di
# Out:
# {'name': 'sam', 'level': 5}

# %%
# type
type(di)
# Out:
# dict

# %%
# 키(key)로 값 출력하기
# print(dictbox['name'])
# print(dictbox['level'])])
print(di['name'])
print(di['level'])
# Out:
# sam
# 5

# %%
# 값 변경하기
# dictbox['level'] = 6
# dictbox['level']
di['name'] = '네모'
di
# Out:
# {'name': '네모', 'level': 5}

# %%
# dictbox.keys()
di.keys()
# Out:
# dict_keys(['name', 'level'])

# %%
# dictbox.values()
di.values()
# Out:
# dict_values(['네모', 5])

# %%
listbox = [2,4,6,8,10]
# list[index] 원소값
# print(listbox[0]) # index 첫번째값
# print(listbox[3]) # index 3 (네번째값)
listbox[4]
# Out:
# 10

# %%
# index 마지막값
# print(listbox[-1])
listbox[-1]
# Out:
# 10

# %%
# list[start:stop]
# index 0부터 2까지
# print(listbox[0:3])
listbox = [2,4,6,8,10]
listbox[:3]
# Out:
# [2, 4, 6]

# %%
# index 3부터 끝까지
# print(listbox[3:])
listbox[3:]
# Out:
# [8, 10]

# %%
# index 1부터 2까지
# print(listbox[1:3])
listbox[1:3]
# Out:
# [4, 6]

# %%
# list[start:stop:step]
# index 처음부터 끝까지, 한칸 건너띄기
# listbox[::2]
listbox[::2]
# Out:
# [2, 6, 10]

# %%
# 합계
# listbox = [4,2,10,6,8]
# sum(listbox)

sum(listbox)
# Out:
# 30

# %%
# 최대값
# max(listbox)
max(listbox)
# Out:
# 10

# %%
# 최소값
# min(listbox)
min(listbox)
# Out:
# 2

# %%
# 길이(갯수)
# len(listbox)

len(listbox)
# Out:
# 5

# %%
# 반올림
# round(1.2345, 2)
# round(1.2347, 2)
round(1.2345, 2) # 1.24
round(1.2416, 2) # 1.24
# Out:
# 1.24

# %%
# 한 단어 변경
text="빅데이터 분석기사 파이썬 공부"
text = text.replace("공부","스터디")
text
# Out:
# '빅데이터 분석기사 파이썬 스터디'

# %%
# 여러 단어 변경
text="빅데이터 분석기사 파이썬 공부"
text = text.replace("파이썬","머신러닝").replace("분석기사","분석을 위한")
text
# Out:
# '빅데이터 분석을 위한 머신러닝 공부'

# %%
# 문자열 슬라이싱
# text[:2]
text[:2]
# Out:
# '빅데'

# %%
# 월-일
date = '2022-12-25'
date[5:]
# Out:
# '12-25'

# %%
# 월만 출력
date = '2022-12-25'
date[5:7]
# Out:
# '12'

# %%
listbox = ['감사','행복','사랑','습관','긍정','변화','성장','공감','희망']
listbox
# Out:
# ['감사', '행복', '사랑', '습관', '긍정', '변화', '성장', '공감', '희망']

# %%
# 갯수
len(listbox)
# Out:
# 9

# %%
# 첫번째 값
listbox[0]
# print(listbox[:1]);
# Out:
# '감사'

# %%
# 마지막 값
listbox[-1]
# print(listbox[-1:]);
# Out:
# '희망'

# %%
# 처음부터 세번째 값까지
print(listbox[:3]);
# Out:
# ['감사', '행복', '사랑']

# %%
# 마지막 앞 단어
listbox[-2:-1]
listbox[7:8]
listbox[7:-1]
# Out:
# ['공감']

# %%
# 행복과 사랑만 출력
listbox[1:3]
# Out:
# ['행복', '사랑']

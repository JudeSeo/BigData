# %%
import pandas as pd
train = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/6_2/energy_train.csv")
test = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/6_2/energy_test.csv")

train.head()
# Out:
#    Compac  Surf_Area  Wall_Area    Roof Height Orient  Glaze_Area  \
# 0    0.74      686.0      245.0   220.5  Short  South        0.25
# 1    0.98      514.5      294.0   Small   Tall  South        0.40
# 2    0.90      563.5      318.5  Medium   Tall   West        0.25
# 3    0.74      686.0      245.0   220.5  Short  South        0.25
# 4    0.98      514.5      294.0   Small   Tall   East        0.25
#
#    Glaze_Distr  Cool_Load Heat_Load
# 0            3      14.72  Very Low
# 1            2      33.94      High
# 2            1      37.58      High
# 3            2      15.18  Very Low
# 4            2      29.69      High

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Compac       537 non-null    float64
#  1   Surf_Area    537 non-null    float64
#  2   Wall_Area    537 non-null    float64
#  3   Roof         537 non-null    object
#  4   Height       537 non-null    object
#  5   Orient       537 non-null    object
#  6   Glaze_Area   537 non-null    float64
#  7   Glaze_Distr  537 non-null    int64
#  8   Cool_Load    537 non-null    float64
#  9   Heat_Load    537 non-null    object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 42.1+ KB

# %%
train.shape, test.shape
# Out:
# ((537, 10), (231, 9))

# %%
train['Heat_Load'].value_counts()
# Out:
# Heat_Load
# Very Low     142
# Low          123
# High         122
# Very High     79
# Medium        71
# Name: count, dtype: int64

# %%
train.isnull().sum()
test.isnull().sum()
# Out:
# Compac         0
# Surf_Area      0
# Wall_Area      0
# Roof           0
# Height         0
# Orient         0
# Glaze_Area     0
# Glaze_Distr    0
# Cool_Load      0
# dtype: int64

# %%
target = train.pop('Heat_Load')

# %%
cols = train.select_dtypes(include='O').columns

# %%
from sklearn.preprocessing import LabelEncoder
for col in cols:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    if(col != 'Heat_Load'):
        test[col] = le.transform(test[col])

# %%
target.value_counts()
# Out:
# Heat_Load
# 4    142
# 1    123
# 0    122
# 3     79
# 2     71
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(train, target)
pred = model.predict(test)

# %%
pred
# Out:
# array([1, 0, 0, 1, 1, 4, 4, 4, 0, 1, 3, 1, 4, 2, 3, 1, 4, 1, 4, 4, 4, 3,
#        0, 4, 0, 1, 0, 0, 1, 1, 0, 4, 1, 2, 3, 0, 3, 3, 1, 3, 4, 2, 4, 3,
#        0, 1, 4, 1, 1, 0, 0, 2, 4, 1, 4, 0, 4, 0, 3, 2, 4, 1, 4, 0, 4, 1,
#        3, 1, 4, 3, 0, 1, 1, 2, 4, 0, 0, 0, 4, 4, 0, 1, 2, 1, 1, 4, 1, 1,
#        0, 4, 4, 3, 0, 4, 0, 0, 0, 4, 2, 1, 0, 1, 2, 0, 3, 2, 2, 0, 1, 4,
#        4, 4, 2, 3, 4, 3, 0, 0, 3, 4, 4, 1, 4, 4, 0, 1, 1, 1, 1, 0, 3, 4,
#        4, 2, 1, 3, 3, 4, 1, 4, 4, 3, 1, 4, 1, 1, 3, 1, 4, 2, 4, 1, 3, 0,
#        4, 1, 0, 2, 1, 1, 4, 1, 1, 4, 2, 2, 1, 0, 4, 0, 0, 1, 3, 1, 1, 0,
#        0, 2, 1, 2, 0, 2, 4, 1, 2, 4, 1, 1, 4, 4, 0, 1, 4, 4, 1, 3, 4, 3,
#        3, 1, 1, 3, 4, 0, 4, 1, 2, 1, 2, 4, 2, 1, 1, 4, 4, 2, 4, 4, 1, 0,
#        0, 1, 1, 4, 0, 0, 4, 2, 4, 1, 3])
